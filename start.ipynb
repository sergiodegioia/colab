# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiodegioia/colab/blob/master/start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 256
t = np.arange( 0, 1, 1/N)
y = np.sin( 2 * np.pi * t)
fig, ax = plt.subplots()
ax.plot( t, y)
